# %%
import sys
from pathlib import Path

import pandas as pd
import requests

# import hbsir

# The following code is written to import hbsir library from this
# repository without installation. Usually, you can import the library
# by writing "import hbsir"

for parent in Path().absolute().parents:
    if len(list(parent.glob("hbsir"))) > 0:
        hbsir_path = parent
        break
else:
    raise FileNotFoundError
sys.path.append(str(hbsir_path))

import hbsir

# %%
if not Path("results.xlsx").exists():
    url = r"https://amar.org.ir/Portals/0/Files/fulltext/1400/NE_HazineDaramad_Shahri_1400.xlsx?ver=zqQ-kIijyzYMGO7lJtouBg%3d%3d"
    request_result = requests.get(url)
    excel_content = request_result.content
    with open("results.xlsx", mode="wb") as excel_file:
        excel_file.write(excel_content)

results: dict[str, pd.DataFrame] = {}
with pd.ExcelFile("results.xlsx") as excel_file:
    for sheet in excel_file.book.sheetnames:
        results[sheet] = pd.read_excel(excel_file, sheet_name=sheet)

# %%
results["U1400Os99T1_04"]
# Out:
#   ۴-۱- درصد خانوارها‌ي شهری بر حسب وضع فعاليت سرپرست خانوار در هر يك از گروه‌هاي هزينه سالانه: ۱۴۰۰  \
# 0                                                شرح
# 1                                                جمع
# 2                                               شاغل
# 3                                  بيکار (جوياي کار)
# 4                               داراي درامد بدون کار
# 5                                               محصل
# 6                                           خانه‌دار
# 7                                               ساير
#
#   Unnamed: 1                Unnamed: 2                    Unnamed: 3  \
# 0         کل  ۱۲۰،۰۰۰ هزار ريال و كمتر  ۱۲۰،۰۰۰ تا ۱۹۵،۰۰۰ هزار ريال
# 1        100                       100                           100
# 2      58.82                     35.27                         24.64
# 3       1.48                      3.35                          4.53
# 4      36.16                     40.71                         56.66
# 5       0.01                         0                          0.06
# 6       2.06                      9.22                          7.62
# 7       1.46                     11.45                          6.49
#
#                       Unnamed: 4                     Unnamed: 5  \
# 0  ۱۹۵،۰۰۰ تا  ۲۷۰،۰۰۰ هزار ريال  ۲۷۰،۰۰۰ تا  ۳۶۰،۰۰۰ هزار ريال
# 1                            100                            100
# 2                          37.89                          47.15
# 3                           2.39                           2.21
# 4                          53.86                          45.44
# 5                              0                              0
# 6                           3.78                           3.88
# 7                           2.09                           1.31
#
#                      Unnamed: 6                    Unnamed: 7  \
# 0  ۳۶۰،۰۰۰ تا ۴۸۰،۰۰۰ هزار ريال  ۴۸۰،۰۰۰ تا ۶۰۰،۰۰۰ هزار ريال
# 1                           100                           100
# 2                         55.68                         63.14
# 3                          2.09                          1.24
# 4                         38.56                         32.04
# 5                             0                             0
# 6                          2.16                          2.45
# 7                          1.51                          1.14
#
#                      Unnamed: 8                    Unnamed: 9  \
# 0  ۶۰۰،۰۰۰ تا ۷۲۰،۰۰۰ هزار ريال  ۷۲۰،۰۰۰ تا ۹۰۰،۰۰۰ هزار ريال
# 1                           100                           100
# 2                         64.55                         62.02
# 3                          1.12                          1.12
# 4                         31.11                         34.62
# 5                          0.05                             0
# 6                          0.93                          1.23
# 7                          2.25                          1.01
#
#                         Unnamed: 10                  Unnamed: 11
# 0  ۹۰۰،۰۰۰  تا ۱،۲۰۰،۰۰۰ هزار ريال   ۱،۲۰۰،۰۰۰ هزار ريال و بيشتر
# 1                               100                          100
# 2                             60.28                        62.18
# 3                              1.62                         0.96
# 4                             35.66                        34.09
# 5                              0.02                            0
# 6                              1.75                         1.61
# 7                              0.66                         1.17
